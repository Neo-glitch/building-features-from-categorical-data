# %%
#10th notebook

from sklearn.preprocessing import KBinsDiscretizer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
car_data = pd.read_csv("./datasets/auto-mpg.csv", na_values="?")

car_data.sample(8)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 233  29.0          4          97.0        78.0    1940          14.5
# 311  32.1          4          98.0        70.0    2120          15.5
# 89   15.0          8         318.0       150.0    3777          12.5
# 128  15.0          6         250.0       100.0    3336          17.0
# 69   12.0          8         350.0       160.0    4456          13.5
# 9    15.0          8         390.0       190.0    3850           8.5
# 157  15.0          8         350.0       145.0    4440          14.0
# 290  15.5          8         351.0       142.0    4054          14.3
#
#      model year  origin                    car name
# 233          77       2    volkswagen rabbit custom
# 311          80       1          chevrolet chevette
# 89           73       1        dodge coronet custom
# 128          74       1              chevrolet nova
# 69           72       1  oldsmobile delta 88 royale
# 9            70       1          amc ambassador dpl
# 157          75       1           chevrolet bel air
# 290          79       1    ford country squire (sw)

# %%
car_data.drop(columns = ["car name", "origin", "model year"], inplace = True)

car_data.dropna(inplace = True)
car_data.reset_index(inplace = True, drop = True)
car_data.sample(6)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration
# 112  21.0          6         155.0       107.0    2472          14.0
# 305  26.8          6         173.0       115.0    2700          12.9
# 105  12.0          8         350.0       180.0    4499          12.5
# 369  36.0          4         105.0        74.0    1980          15.3
# 127  31.0          4          79.0        67.0    1950          19.0
# 278  21.5          6         231.0       115.0    3245          15.4

# %%
# eda
fig, ax = plt.subplots(figsize = (12, 8))

plt.scatter(car_data["displacement"], car_data["horsepower"], color = "red")
ax.set(xlabel = "Engnie Displacement", ylabel = "HorsePower",
      title = "Displacement vs horsePower")
ax.grid()
plt.show()


# shows linear relationship

# %%
k_bins = KBinsDiscretizer(n_bins = 5,
                        encode = "ordinal",  # ret bin identifier encoded as int value
                        strategy="uniform") # bins have same width

k_bins
# Out:
# KBinsDiscretizer(encode='ordinal', strategy='uniform')

# %%
k_bins_array = k_bins.fit_transform(car_data[["displacement", "horsepower"]])

kbins_df = pd.DataFrame(data = k_bins_array, columns = ["bin_displacement", "bin_horsepower"])
kbins_df.sample(6)
# Out:
#      bin_displacement  bin_horsepower
# 309               0.0             0.0
# 108               0.0             0.0
# 204               0.0             0.0
# 49                0.0             1.0
# 188               3.0             2.0
# 166               0.0             1.0

# %%
# concat bin df with main df
car_data_k_bins = pd.concat([car_data, kbins_df], axis = 1)

car_data_k_bins.sample(6)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 227  16.0          8         400.0       180.0    4220          11.1
# 310  37.2          4          86.0        65.0    2019          16.4
# 292  34.1          4          86.0        65.0    1975          15.2
# 86   13.0          8         350.0       145.0    3988          13.0
# 146  26.0          4         116.0        75.0    2246          14.0
# 153  15.0          6         250.0        72.0    3158          19.5
#
#      bin_displacement  bin_horsepower
# 227               4.0             3.0
# 310               0.0             0.0
# 292               0.0             0.0
# 86                3.0             2.0
# 146               0.0             0.0
# 153               2.0             0.0

# %%
# find the unique bins for displacement
car_data_k_bins["bin_displacement"].unique()
# Out:
# array([3., 4., 0., 1., 2.])

# %%
# to check bin spacing of bin_displacment and bin_horsepower
displacement_edges = k_bins.bin_edges_[0]
horsepower_edges = k_bins.bin_edges_[1]

displacement_edges, horsepower_edges
# Out:
# (array([ 68. , 145.4, 222.8, 300.2, 377.6, 455. ]),
#  array([ 46. ,  82.8, 119.6, 156.4, 193.2, 230. ]))

# %%
car_data_k_bins["Comment"] = ''
car_data_k_bins.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    bin_displacement  bin_horsepower Comment
# 0               3.0             2.0
# 1               3.0             3.0
# 2               3.0             2.0
# 3               3.0             2.0
# 4               3.0             2.0

# %%
car_data_k_bins.loc[car_data_k_bins["bin_displacement"] < 
                   car_data_k_bins["bin_horsepower"],
                   "Comment"] = "Efficient"

# %%
car_data_k_bins.loc[car_data_k_bins["bin_displacement"] > 
                   car_data_k_bins["bin_horsepower"],
                   "Comment"] = "Infficient"

# %%
car_data_k_bins.sample(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 227  16.0          8         400.0       180.0    4220          11.1
# 228  15.5          8         350.0       170.0    4165          11.4
# 381  38.0          6         262.0        85.0    3015          17.0
# 243  36.1          4          98.0        66.0    1800          14.4
# 261  17.7          6         231.0       165.0    3445          13.4
# 215  30.0          4         111.0        80.0    2155          14.8
# 223  17.5          6         250.0       110.0    3520          16.4
# 33   16.0          6         225.0       105.0    3439          15.5
# 96   18.0          6         225.0       105.0    3121          16.5
# 51   30.0          4          88.0        76.0    2065          14.5
#
#      bin_displacement  bin_horsepower     Comment
# 227               4.0             3.0  Infficient
# 228               3.0             3.0
# 381               2.0             1.0  Infficient
# 243               0.0             0.0
# 261               2.0             3.0   Efficient
# 215               0.0             0.0
# 223               2.0             1.0  Infficient
# 33                2.0             1.0  Infficient
# 96                2.0             1.0  Infficient
# 51                0.0             0.0

# %%
# data viz
fig, ax = plt.subplots(figsize = (10, 8))


categories = car_data_k_bins["Comment"].unique()

colors = {categories[0]: "green",
         categories[1]: "red",
         categories[2]: "blue"}

# plots scatter and colors points based on cat they belong to based on Comments col
ax.scatter(car_data_k_bins["displacement"],
          car_data_k_bins["horsepower"],
          c = car_data_k_bins["Comment"].apply(lambda x: colors[x]))

ax.set(xlabel = "Engine Displacement",
          ylabel = "HorsePower",
          title = "Displacement vs HorsePower")

ax.grid()
ax.set_xticks(displacement_edges)
ax.set_yticks(horsepower_edges)

plt.show()
